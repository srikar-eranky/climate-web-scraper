# %%
from ams.ams_node import AmsNode
from ams.ams_journal_node import AmsJournalNode
from custom_driver import get_page_content
import requests

# node = AmsNode('AMS')
# node.expand_node()
# journal_node = AmsJournalNode(name="aies",url="https://journals.ametsoc.org/view/journals/aies/aies-overview.xml?contents=all-volumes",
#                               base_url="https://journals.ametsoc.org/",parent=None)
# print(journal_node.get_name())

# %%
page_contents = get_page_content(url='https://journals.ametsoc.org/view/journals/aies/3/1/aies.3.issue-1.xml')
print(page_contents)
print(type(page_contents))

# %%
page_contents = page_contents.strip()

# %%
page_contents
# Out:
# '<html data-locale="en" lang="en" class="no-js"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-0S4LETTN6J&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-E46N5C155L&amp;l=dataLayer&amp;cx=c"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-MDF62SW"></script><script src="https://prod-apm-public-files.s3.amazonaws.com/5.9.1/elastic-apm-rum.umd.js"></script><script>window.dataLayer = window.dataLayer || [];dataLayer.push({\n  "pf:selectedLanguage" : "English",\n  "pf:sitegenUUid" : "44595435006693760",\n  "pf:contentType" : "TITLE",\n  "pf:contentCategory" : "nlm-journal-issue",\
# ...

# %%
page_contents.find("Articles")
# Out:
# -1

# %%
response = requests.get('https://journals.ametsoc.org/view/journals/aies/3/1/aies.3.issue-1.xml')
print(response)
# Out:
# <Response [403]>
